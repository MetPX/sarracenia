# %% [markdown]
# # flow api example
#
# The sarracenia.flow class provides built in accept/reject filtering for messages, supports built-in downloading in several protocols, retries on failure, and allows the creation of callbacks, to customize processing.
#
# You need to provide a configuration as an argument when instantiating a subscriber.
# the _sarracenia.config.no_file_config()_ returns an empty configuration without consulting
# any of the sr3 configuration file tree.
#
# After adding the modifications needed to the configuration, the subscriber is then initiated and run.

# %%
# !mkdir /tmp/flow_demo
# Out:
# mkdir: cannot create directory ‘/tmp/flow_demo’: File exists

# %%
import re
import sarracenia.config
from sarracenia.flow.subscribe import Subscribe
import sarracenia.flowcb

from urllib.parse import urlparse

cfg = sarracenia.config.no_file_config()

cfg.broker = urlparse('amqps://anonymous:anonymous@hpfx.collab.science.gc.ca')
cfg.bindings = [ ('v02.post', 'xpublic', '*.WXO-DD.observations.swob-ml.#') ]
cfg.queue_name='q_anonymous.subscriber_test2'
cfg.download=True
cfg.batch=1
cfg.message_count_max=5

pattern=".*"
cfg.masks= [ ( pattern, "/tmp/flow_demo", None, re.compile(pattern), True, False, False, False, '/' ) ]

subscriber = sarracenia.flow.subscribe.Subscribe( cfg )

subscriber.run()
# Out:
# 2021-02-15 08:26:08,786 [INFO] sarracenia.flow loadCallbacks imports to load: []
# 2021-02-15 08:26:08,787 [DEBUG] sarracenia.flowcb.retry __init__ sr_retry __init__
# 2021-02-15 08:26:08,787 [DEBUG] sarracenia.flowcb.retry __init__ logLevel=info
# 2021-02-15 08:26:08,908 [DEBUG] amqp _on_start Start from server, version: 0.9, properties: {'capabilities': {'publisher_confirms': True, 'exchange_exchange_bindings': True, 'basic.nack': True, 'consumer_cancel_notify': True, 'connection.blocked': True, 'consumer_priorities': True, 'authentication_failure_close': True, 'per_consumer_qos': True, 'direct_reply_to': True}, 'cluster_name': 'rabbit@hpfx2.collab.science.gc.ca', 'copyright': 'Copyright (C) 2007-2019 Pivotal Software, Inc.', 'information': 'Licensed under the MPL.  See http://www.rabbitmq.com/', 'platform': 'Erlang/OTP 21.3', 'product': 'RabbitMQ', 'version': '3.7.13'}, mechanisms: [b'PLAIN', b'AMQPLAIN'], locales: ['en_US']
# 2021-02-15 08:26:08,947 [DEBUG] amqp __init__ using channel_id: 1
# 2021-02-15 08:26:08,963 [DEBUG] amqp _on_open_ok Channel open
# 2021-02-15 08:26:09,022 [INFO] sarracenia.moth.amqp __getSetup queue declared q_anonymous.subscriber_test2 (as: amqps://anonymous@hpfx.collab.science.gc.ca)
# 2021-02-15 08:26:09,023 [INFO] sarracenia.moth.amqp __getSetup binding q_anonymous.subscriber_test2 with v02.post.*.WXO-DD.observations.swob-ml.# to xpublic (as: amqps://anonymous@hpfx.collab.science.gc.ca)
# 2021-02-15 08:26:09,045 [DEBUG] sarracenia.moth.amqp __getSetup getSetup ... Done!
# 2021-02-15 08:26:09,045 [DEBUG] sarracenia.config check_undeclared_options start
# 2021-02-15 08:26:09,045 [DEBUG] sarracenia.config check_undeclared_options done
# 2021-02-15 08:26:09,046 [DEBUG] sarracenia.flow run working directory: /home/peter/Projects/jupyter
# 2021-02-15 08:26:09,046 [INFO] sarracenia.flow run options:
# 2021-02-15 08:26:09,051 [INFO] sarracenia.flow run callbacks loaded: ['sarracenia.flowcb.retry.Retry', 'sarracenia.flowcb.v2wrapper.V2Wrapper', 'sarracenia.flowcb.gather.message.Message']
# 2021-02-15 08:26:09,051 [INFO] sarracenia.flowcb.retry on_start sr_retry on_start
# 2021-02-15 08:26:09,055 [INFO] sarracenia.flowcb.v2wrapper on_time v2 run on_start
# 2021-02-15 08:26:09,071 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'DDSR.CMC,DDI.CMC,CMC,SCIENCE,EDM', 'filename': 'msg_ddsr-WXO-DD_5533f81ee7e9888b2f6f17f0de596913:DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'source': 'WXO-DD', 'mtime': '20210215T132606.18', 'atime': '20210215T132606.18', 'topic': 'v02.post.20210215.WXO-DD.observations.swob-ml.20210215.CNCN', '_deleteOnPost': ['delivery_tag', 'exchange', 'local_offset', 'topic'], 'pubTime': '20210215T132606.18', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20210215/WXO-DD/observations/swob-ml/20210215/CNCN/2021-02-15-1325-CNCN-AUTO-minute-swob.xml', 'integrity': {'method': 'md5', 'value': 'h6sojHI+BTKIRu8NGZOOIg=='}, 'size': 9602, 'exchange': 'xpublic', 'delivery_tag': 1, 'local_offset': 0}
# 2021-02-15 08:26:09,072 [DEBUG] sarracenia.flow ackOKandRejected A gathered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,072 [DEBUG] sarracenia.flow ackOKandRejected B filtered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,072 [DEBUG] sarracenia.flow download https_transport download
# 2021-02-15 08:26:09,073 [DEBUG] sarracenia.flow download https_transport download connects
# 2021-02-15 08:26:09,073 [DEBUG] sarracenia.transfer __init__ sr_proto __init__: subclasses=[<class 'sarracenia.transfer.ftp.Ftp'>, <class 'sarracenia.transfer.sftp.Sftp'>, <class 'sarracenia.transfer.https.Https'>, <class 'sarracenia.transfer.file.File'>]
# 2021-02-15 08:26:09,073 [DEBUG] sarracenia.transfer.https init sr_http init
# 2021-02-15 08:26:09,073 [DEBUG] sarracenia.transfer.https __init__ sr_http __init__
# 2021-02-15 08:26:09,074 [DEBUG] sarracenia.transfer.https init sr_http init
# 2021-02-15 08:26:09,074 [DEBUG] sarracenia.flow download HOHO proto <class 'dict'>
# 2021-02-15 08:26:09,074 [DEBUG] sarracenia.transfer.https connect sr_http connect https://hpfx.collab.science.gc.ca
# 2021-02-15 08:26:09,074 [DEBUG] sarracenia.transfer.https credentials sr_http credentials https://hpfx.collab.science.gc.ca
# 2021-02-15 08:26:09,075 [DEBUG] sarracenia.flow download connected
# 2021-02-15 08:26:09,075 [DEBUG] sarracenia.flow download  proto <class 'sarracenia.transfer.https.Https'>
# 2021-02-15 08:26:09,075 [DEBUG] sarracenia.flow download https_transport download cd to //20210215/WXO-DD/observations/swob-ml/20210215/CNCN
# 2021-02-15 08:26:09,075 [DEBUG] sarracenia.transfer.https cd sr_http cd //20210215/WXO-DD/observations/swob-ml/20210215/CNCN
# 2021-02-15 08:26:09,075 [DEBUG] sarracenia.flow download Beginning fetch of https://hpfx.collab.science.gc.ca//20210215/WXO-DD/observations/swob-ml/20210215/CNCN/2021-02-15-1325-CNCN-AUTO-minute-swob.xml  into 2021-02-15-1325-CNCN-AUTO-minute-swob.xml 0-9601
# 2021-02-15 08:26:09,075 [DEBUG] sarracenia.transfer set_sumalgo sr_proto set_sumalgo md5
# 2021-02-15 08:26:09,076 [DEBUG] sarracenia.flow download hasattr=True, thresh=0, len=9602, remote_off=0, local_off=0
# 2021-02-15 08:26:09,076 [DEBUG] sarracenia.transfer.https get sr_http get 2021-02-15-1325-CNCN-AUTO-minute-swob.xml 2021-02-15-1325-CNCN-AUTO-minute-swob.xml 0
# 2021-02-15 08:26:09,076 [DEBUG] sarracenia.transfer.https get sr_http self.path //20210215/WXO-DD/observations/swob-ml/20210215/CNCN
# 2021-02-15 08:26:09,076 [DEBUG] sarracenia.transfer.https __open__ sr_http open
# 2021-02-15 08:26:09,206 [DEBUG] sarracenia.transfer read_write sr_proto read_write
# 2021-02-15 08:26:09,214 [INFO] sarracenia.flow do_download downloaded ok: /tmp/flow_demo/2021-02-15-1325-CNCN-AUTO-minute-swob.xml
# 2021-02-15 08:26:09,214 [INFO] sarracenia.flow.subscribe do processing 1 messages worked!
# 2021-02-15 08:26:09,215 [WARNING] sarracenia.flow run message_count_max: 5, total_messages: 1 last_gather_len: 1
# 2021-02-15 08:26:09,215 [DEBUG] sarracenia.flow run worked too long to sleep!
# 2021-02-15 08:26:09,241 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'DDSR.CMC,DDI.CMC,CMC,SCIENCE,EDM', 'filename': 'msg_ddsr-WXO-DD_5b9569d954a2d1115bc511d0d3c97d5d:DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'source': 'WXO-DD', 'mtime': '20210215T132606.19', 'atime': '20210215T132606.19', 'topic': 'v02.post.20210215.WXO-DD.observations.swob-ml.20210215.CADN', '_deleteOnPost': ['delivery_tag', 'exchange', 'local_offset', 'topic'], 'pubTime': '20210215T132606.19', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20210215/WXO-DD/observations/swob-ml/20210215/CADN/2021-02-15-1325-CADN-AUTO-minute-swob.xml', 'integrity': {'method': 'md5', 'value': 'OSl5FcfI0RsclCv9LMoolg=='}, 'size': 9854, 'exchange': 'xpublic', 'delivery_tag': 2, 'local_offset': 0}
# 2021-02-15 08:26:09,242 [DEBUG] sarracenia.flow ackOKandRejected A gathered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,242 [DEBUG] sarracenia.flow ackOKandRejected B filtered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,243 [DEBUG] sarracenia.flow download https_transport download
# 2021-02-15 08:26:09,243 [DEBUG] sarracenia.transfer.https check_is_connected sr_http check_is_connected
# 2021-02-15 08:26:09,243 [DEBUG] sarracenia.flow download  proto <class 'sarracenia.transfer.https.Https'>
# 2021-02-15 08:26:09,243 [DEBUG] sarracenia.flow download https_transport download cd to //20210215/WXO-DD/observations/swob-ml/20210215/CADN
# 2021-02-15 08:26:09,243 [DEBUG] sarracenia.transfer.https cd sr_http cd //20210215/WXO-DD/observations/swob-ml/20210215/CADN
# 2021-02-15 08:26:09,244 [DEBUG] sarracenia.flow download Beginning fetch of https://hpfx.collab.science.gc.ca//20210215/WXO-DD/observations/swob-ml/20210215/CADN/2021-02-15-1325-CADN-AUTO-minute-swob.xml  into 2021-02-15-1325-CADN-AUTO-minute-swob.xml 0-9853
# 2021-02-15 08:26:09,244 [DEBUG] sarracenia.transfer set_sumalgo sr_proto set_sumalgo md5
# 2021-02-15 08:26:09,244 [DEBUG] sarracenia.flow download hasattr=True, thresh=0, len=9854, remote_off=0, local_off=0
# 2021-02-15 08:26:09,244 [DEBUG] sarracenia.transfer.https get sr_http get 2021-02-15-1325-CADN-AUTO-minute-swob.xml 2021-02-15-1325-CADN-AUTO-minute-swob.xml 0
# 2021-02-15 08:26:09,245 [DEBUG] sarracenia.transfer.https get sr_http self.path //20210215/WXO-DD/observations/swob-ml/20210215/CADN
# 2021-02-15 08:26:09,245 [DEBUG] sarracenia.transfer.https __open__ sr_http open
# _Config__admin=None, _Config__broker=amqps://anonymous@hpfx.collab.science.gc.ca, _Config__post_broker=None, accel_threshold=0, accept_unmatch=True,
# accept_unmatched=False, attempts=3, auto_delete=False, baseDir=None, batch=1, bind=True,
# bindings=[('v02.post', 'xpublic', '*.WXO-DD.observations.swob-ml.#')], bufsize=1048576, bytes_per_second=None, bytes_ps=0, cfg_run_dir='.', chmod=0,
# chmod_dir=509, chmod_log=384, currentDir=None, debug=False, declare=True, declared_exchanges=[], declared_users={}, delete=False, destfn_script=None,
# directory=None, documentRoot=None, download=True, durable=True, exchange=None, expire=300, filename=None, fixed_headers={}, flatten='/', hostdir='fractal',
# hostname='fractal', housekeeping=30, imports=[], inflight=None, inline=False, inline_encoding='guess', inline_max=4096, instances=1,
# logFormat='%(asctime)s [%(levelname)s] %(name)s %(funcName)s %(message)s', logLevel='info', log_reject=False, lr_backupCount=5, lr_interval=1,
# lr_when='midnight', masks="...*', '/tmp/flow_demo', None, re.compile('.*'), True, False, False, False, '/')]", message_count_max=5, message_rate_max=0,
# message_rate_min=0, message_strategy={'reset': True, 'stubborn': True, 'failure_duration': '5m'}, message_ttl=0, mirror=True, notify_only=False,
# overwrite=True, plugins=[], post_baseDir=None, post_baseUrl=None, post_documentRoot=None, post_exchanges=[], post_topic_prefix='v02.post', prefetch=25,
# preserve_mode=True, preserve_time=True, pstrip=False, queue_name='q_anonymous.subscriber_test2', randid='2c1e', realpath_post=False, report_back=False,
# reset=False, retry_path='.', settings={}, sleep=0.1, statehost=False, strip=0, subtopic=None, suppress_duplicates=0, timeout=300, tls_rigour='normal',
# topic_prefix='v02.post', undeclared=[], users=False, v2plugin_options=[], v2plugins={}, vhost='/', vip=None
# 2021-02-15 08:26:09,355 [DEBUG] sarracenia.transfer read_write sr_proto read_write
# 2021-02-15 08:26:09,358 [INFO] sarracenia.flow do_download downloaded ok: /tmp/flow_demo/2021-02-15-1325-CADN-AUTO-minute-swob.xml
# 2021-02-15 08:26:09,359 [INFO] sarracenia.flow.subscribe do processing 1 messages worked!
# 2021-02-15 08:26:09,359 [WARNING] sarracenia.flow run message_count_max: 5, total_messages: 2 last_gather_len: 1
# 2021-02-15 08:26:09,359 [DEBUG] sarracenia.flow run worked too long to sleep!
# 2021-02-15 08:26:09,379 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'DDSR.CMC,DDI.CMC,CMC,SCIENCE,EDM', 'filename': 'msg_ddsr-WXO-DD_65719e985cf4afff489c4dea1e3f3d70:DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'source': 'WXO-DD', 'mtime': '20210215T132606.20', 'atime': '20210215T132606.20', 'topic': 'v02.post.20210215.WXO-DD.observations.swob-ml.20210215.CMTH', '_deleteOnPost': ['delivery_tag', 'exchange', 'local_offset', 'topic'], 'pubTime': '20210215T132606.20', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20210215/WXO-DD/observations/swob-ml/20210215/CMTH/2021-02-15-1325-CMTH-AUTO-minute-swob.xml', 'integrity': {'method': 'md5', 'value': 'Akh2M0kOBWideGAIRxDoPA=='}, 'size': 9848, 'exchange': 'xpublic', 'delivery_tag': 3, 'local_offset': 0}
# 2021-02-15 08:26:09,379 [DEBUG] sarracenia.flow ackOKandRejected A gathered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,380 [DEBUG] sarracenia.flow ackOKandRejected B filtered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,380 [DEBUG] sarracenia.flow download https_transport download
# 2021-02-15 08:26:09,380 [DEBUG] sarracenia.transfer.https check_is_connected sr_http check_is_connected
# 2021-02-15 08:26:09,380 [DEBUG] sarracenia.flow download  proto <class 'sarracenia.transfer.https.Https'>
# 2021-02-15 08:26:09,381 [DEBUG] sarracenia.flow download https_transport download cd to //20210215/WXO-DD/observations/swob-ml/20210215/CMTH
# 2021-02-15 08:26:09,381 [DEBUG] sarracenia.transfer.https cd sr_http cd //20210215/WXO-DD/observations/swob-ml/20210215/CMTH
# 2021-02-15 08:26:09,381 [DEBUG] sarracenia.flow download Beginning fetch of https://hpfx.collab.science.gc.ca//20210215/WXO-DD/observations/swob-ml/20210215/CMTH/2021-02-15-1325-CMTH-AUTO-minute-swob.xml  into 2021-02-15-1325-CMTH-AUTO-minute-swob.xml 0-9847
# 2021-02-15 08:26:09,381 [DEBUG] sarracenia.transfer set_sumalgo sr_proto set_sumalgo md5
# 2021-02-15 08:26:09,382 [DEBUG] sarracenia.flow download hasattr=True, thresh=0, len=9848, remote_off=0, local_off=0
# 2021-02-15 08:26:09,382 [DEBUG] sarracenia.transfer.https get sr_http get 2021-02-15-1325-CMTH-AUTO-minute-swob.xml 2021-02-15-1325-CMTH-AUTO-minute-swob.xml 0
# 2021-02-15 08:26:09,382 [DEBUG] sarracenia.transfer.https get sr_http self.path //20210215/WXO-DD/observations/swob-ml/20210215/CMTH
# 2021-02-15 08:26:09,382 [DEBUG] sarracenia.transfer.https __open__ sr_http open
# 2021-02-15 08:26:09,474 [DEBUG] sarracenia.transfer read_write sr_proto read_write
# 2021-02-15 08:26:09,477 [INFO] sarracenia.flow do_download downloaded ok: /tmp/flow_demo/2021-02-15-1325-CMTH-AUTO-minute-swob.xml
# 2021-02-15 08:26:09,478 [INFO] sarracenia.flow.subscribe do processing 1 messages worked!
# 2021-02-15 08:26:09,478 [WARNING] sarracenia.flow run message_count_max: 5, total_messages: 3 last_gather_len: 1
# 2021-02-15 08:26:09,478 [DEBUG] sarracenia.flow run worked too long to sleep!
# 2021-02-15 08:26:09,497 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'DDSR.CMC,DDI.CMC,CMC,SCIENCE,EDM', 'filename': 'msg_ddsr-WXO-DD_6b1a8bcb0e133518138d97a66b4dde95:DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'source': 'WXO-DD', 'mtime': '20210215T132606.21', 'atime': '20210215T132606.21', 'topic': 'v02.post.20210215.WXO-DD.observations.swob-ml.20210215.CGMG', '_deleteOnPost': ['delivery_tag', 'exchange', 'local_offset', 'topic'], 'pubTime': '20210215T132606.21', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20210215/WXO-DD/observations/swob-ml/20210215/CGMG/2021-02-15-1325-CGMG-AUTO-minute-swob.xml', 'integrity': {'method': 'md5', 'value': 'Rk5F+K82qaf32oFr+KPgOQ=='}, 'size': 9601, 'exchange': 'xpublic', 'delivery_tag': 4, 'local_offset': 0}
# 2021-02-15 08:26:09,497 [DEBUG] sarracenia.flow ackOKandRejected A gathered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,497 [DEBUG] sarracenia.flow ackOKandRejected B filtered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,498 [DEBUG] sarracenia.flow download https_transport download
# 2021-02-15 08:26:09,498 [DEBUG] sarracenia.transfer.https check_is_connected sr_http check_is_connected
# 2021-02-15 08:26:09,498 [DEBUG] sarracenia.flow download  proto <class 'sarracenia.transfer.https.Https'>
# 2021-02-15 08:26:09,498 [DEBUG] sarracenia.flow download https_transport download cd to //20210215/WXO-DD/observations/swob-ml/20210215/CGMG
# 2021-02-15 08:26:09,498 [DEBUG] sarracenia.transfer.https cd sr_http cd //20210215/WXO-DD/observations/swob-ml/20210215/CGMG
# 2021-02-15 08:26:09,499 [DEBUG] sarracenia.flow download Beginning fetch of https://hpfx.collab.science.gc.ca//20210215/WXO-DD/observations/swob-ml/20210215/CGMG/2021-02-15-1325-CGMG-AUTO-minute-swob.xml  into 2021-02-15-1325-CGMG-AUTO-minute-swob.xml 0-9600
# 2021-02-15 08:26:09,499 [DEBUG] sarracenia.transfer set_sumalgo sr_proto set_sumalgo md5
# 2021-02-15 08:26:09,499 [DEBUG] sarracenia.flow download hasattr=True, thresh=0, len=9601, remote_off=0, local_off=0
# 2021-02-15 08:26:09,499 [DEBUG] sarracenia.transfer.https get sr_http get 2021-02-15-1325-CGMG-AUTO-minute-swob.xml 2021-02-15-1325-CGMG-AUTO-minute-swob.xml 0
# 2021-02-15 08:26:09,499 [DEBUG] sarracenia.transfer.https get sr_http self.path //20210215/WXO-DD/observations/swob-ml/20210215/CGMG
# 2021-02-15 08:26:09,500 [DEBUG] sarracenia.transfer.https __open__ sr_http open
# 2021-02-15 08:26:09,586 [DEBUG] sarracenia.transfer read_write sr_proto read_write
# 2021-02-15 08:26:09,589 [INFO] sarracenia.flow do_download downloaded ok: /tmp/flow_demo/2021-02-15-1325-CGMG-AUTO-minute-swob.xml
# 2021-02-15 08:26:09,589 [INFO] sarracenia.flow.subscribe do processing 1 messages worked!
# 2021-02-15 08:26:09,590 [WARNING] sarracenia.flow run message_count_max: 5, total_messages: 4 last_gather_len: 1
# 2021-02-15 08:26:09,590 [DEBUG] sarracenia.flow run worked too long to sleep!
# 2021-02-15 08:26:09,607 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'DDSR.CMC,DDI.CMC,CMC,SCIENCE,EDM', 'filename': 'msg_ddsr-WXO-DD_711cd7b03d2b1280137c196439285a31:DMS:WXO_RENAMED_SWOB2:MSC:XML::20210215132605', 'source': 'WXO-DD', 'mtime': '20210215T132606.22', 'atime': '20210215T132606.22', 'topic': 'v02.post.20210215.WXO-DD.observations.swob-ml.20210215.CWGY', '_deleteOnPost': ['delivery_tag', 'exchange', 'local_offset', 'topic'], 'pubTime': '20210215T132606.22', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20210215/WXO-DD/observations/swob-ml/20210215/CWGY/2021-02-15-1325-CWGY-AUTO-minute-swob.xml', 'integrity': {'method': 'md5', 'value': 'OUtE9Coq2Xcp7klL0BFVbA=='}, 'size': 8819, 'exchange': 'xpublic', 'delivery_tag': 5, 'local_offset': 0}
# 2021-02-15 08:26:09,607 [DEBUG] sarracenia.flow ackOKandRejected A gathered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,607 [DEBUG] sarracenia.flow ackOKandRejected B filtered incoming: 1, ok: 0, rejected: 0, failed: 0
# 2021-02-15 08:26:09,608 [DEBUG] sarracenia.flow download https_transport download
# 2021-02-15 08:26:09,608 [DEBUG] sarracenia.transfer.https check_is_connected sr_http check_is_connected
# 2021-02-15 08:26:09,608 [DEBUG] sarracenia.flow download  proto <class 'sarracenia.transfer.https.Https'>
# 2021-02-15 08:26:09,608 [DEBUG] sarracenia.flow download https_transport download cd to //20210215/WXO-DD/observations/swob-ml/20210215/CWGY
# 2021-02-15 08:26:09,609 [DEBUG] sarracenia.transfer.https cd sr_http cd //20210215/WXO-DD/observations/swob-ml/20210215/CWGY
# 2021-02-15 08:26:09,609 [DEBUG] sarracenia.flow download Beginning fetch of https://hpfx.collab.science.gc.ca//20210215/WXO-DD/observations/swob-ml/20210215/CWGY/2021-02-15-1325-CWGY-AUTO-minute-swob.xml  into 2021-02-15-1325-CWGY-AUTO-minute-swob.xml 0-8818
# 2021-02-15 08:26:09,609 [DEBUG] sarracenia.transfer set_sumalgo sr_proto set_sumalgo md5
# 2021-02-15 08:26:09,609 [DEBUG] sarracenia.flow download hasattr=True, thresh=0, len=8819, remote_off=0, local_off=0
# 2021-02-15 08:26:09,609 [DEBUG] sarracenia.transfer.https get sr_http get 2021-02-15-1325-CWGY-AUTO-minute-swob.xml 2021-02-15-1325-CWGY-AUTO-minute-swob.xml 0
# 2021-02-15 08:26:09,610 [DEBUG] sarracenia.transfer.https get sr_http self.path //20210215/WXO-DD/observations/swob-ml/20210215/CWGY
# 2021-02-15 08:26:09,610 [DEBUG] sarracenia.transfer.https __open__ sr_http open
# 2021-02-15 08:26:09,710 [DEBUG] sarracenia.transfer read_write sr_proto read_write
# 2021-02-15 08:26:09,713 [INFO] sarracenia.flow do_download downloaded ok: /tmp/flow_demo/2021-02-15-1325-CWGY-AUTO-minute-swob.xml
# 2021-02-15 08:26:09,713 [INFO] sarracenia.flow.subscribe do processing 1 messages worked!
# 2021-02-15 08:26:09,714 [WARNING] sarracenia.flow run message_count_max: 5, total_messages: 5 last_gather_len: 1
# 2021-02-15 08:26:09,714 [INFO] sarracenia.flowcb.v2wrapper on_time v2 run on_stop
# 2021-02-15 08:26:09,737 [DEBUG] amqp collect Closed channel #1
# 2021-02-15 08:26:09,738 [INFO] sarracenia.flowcb.gather.message on_stop closing
# 2021-02-15 08:26:09,738 [INFO] sarracenia.flow close flow/close completed cleanly

# %% [markdown]
# ## starters.
# the broker, bindings, and queue_name settings are explained in the moth notebook.
#
# ## cfg.download
#
# Whether you want the flow to download the files corresponding to the messages.
# If true, then it will download the files.
#
# ## cfg.batch
#
# Messages are processed in batches. The number of messages to retrieve per call to newMessages()
# is limited by the _batch_ setting.  We set it to 1 here so you can see each file being downloaded immediately when the corresponding message is downloaded.  you can leave this blank, and it defaults to 25. Settings are matter of taste and use case.
#
# ## cfg.message_count_max
#
# Normally we just leave this setting at it's default (0) which has no effect on processing.
# for demonstration purposes, we limit the number of messages the subscriber will process with this setting.
# after _message_count_max_ messages have been received, stop processing.
#
#
# ## cfg.masks
# masks are a compiled form of accept/reject directives.  a relPath is compared to the regex in the mask.
# If the regex matches, and accept is true, then the message is accepted for further processing.
# If the regex matches, but accept is False, then processing of the message is stopped (the message is rejected.)
#
# masks are a tuple. the meaning can be looked up in the sr3(1) man page.
#
# *  pattern_string,      the input regular expression string, to be compiled by re routines.
# *  directory,           where to put the files downloaded (root of the tree, when mirroring)
# *  fn,                  transformation of filename to do. None is the 99% use case.
# *  regex,               compiled regex version of the pattern_string
# *  accept(True/False),  if pattern matches then accept message for further processing.
# *  mirror(True/False),  when downloading build a complete tree to mirror the source, or just dump in directory
# *  strip(True/False),   modify the relpath by stripping entries from the left.
# *  pstrip(True/False),  strip entries based on patterm
# *  flatten(char ... '/' means do not flatten.) )

# %% [markdown]
# # Conclusion:
#
# With the sarracenia.flow class, an async method of operation is supported, it can be customized using flowcb (flow callback) class to introduce specific processing at specific times. It is just like invocation of a single instance from the command line, except all configuration is done within python by setting cfg fields, rather than using the configuration language.
#
# To use the full configuration language (slightly simpler than assigning values to the cfg object) and to run multiple instances, and have co-ordinated monitoring of the instances (restarts on failure, and a programmable number of subscribers started per configuration.) One should look to using the command line interface (sr3)
# with the configuration file tree.
