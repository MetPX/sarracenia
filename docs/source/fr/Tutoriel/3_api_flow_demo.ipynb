# %% [markdown]
# # Exemple d'API de flux
#
# La [classe sarracenia.flow](../Reference/code.html#module-sarracenia.flow) fournit un filtrage d'acceptation/rejet intégré pour les messages, prend en charge le téléchargement intégré dans plusieurs protocoles, réessaye en cas d'échec et permet la création de rappels pour personnaliser le traitement.
#
# Vous devez fournir une configuration comme argument lors de l'instanciation d'un abonné.
# La _sarracenia.config.no_file_config()_ renvoie une configuration vide sans consulter
# l'arborescence des fichiers de configuration sr3.
#
# Après avoir apporté les modifications nécessaires à la configuration, l'abonné est alors initié et exécuté.

# %%
# !mkdir /tmp/flow_demo

# %% [markdown]
# Créer un répertoire pour les fichiers que vous allez télécharger. La racine de l'arborescence de répertoires doit exister.

# %%
import copy
import re
import sarracenia.config
from sarracenia.flow.subscribe import Subscribe
import sarracenia.flowcb
import sarracenia.config.credentials
import socket

cfg = sarracenia.config.no_file_config()

cfg.broker = sarracenia.config.credentials.Credential(
    'amqps://anonymous:anonymous@hpfx.collab.science.gc.ca')
cfg.topicPrefix = ['v02', 'post']
cfg.component = 'subscribe'
cfg.config = 'flow_demo'
cfg.action = 'foreground'
bindings = [ {'exchange':'xpublic', 'prefix':['v02', 'post'],
                'sub':['*.WXO-DD.observations.swob-ml.#']}]
cfg.queueName = 'q_${BROKER_USER}_${HOSTNAME}_${QUEUESHARE}'
cfg.download = True
cfg.batch = 1
cfg.logReject = True
cfg.expire = 600
cfg.messageCountMax = 5
cfg.queueShare = 'SomethingSessionfulToYou'


cfg.settings = { 'sarracenia.moth.amqp.AMQP': { 'logLevel':'debug' } }


# Note: queue name must start with q_<username> because server is configured to deny anything else.
#

queue = {'name': 'q_anonymous_' + socket.getfqdn() + '_' + cfg.queueShare,
         'template': cfg.queueName,
         'auto_delete' : False, # AO == amqp only
         'durable': True, # AO: queue should survive broker reboots
         'expire': 600,  # MO: seconds until queue with no consumers disappears.
         'prefetch': 5,
         'qos': 1,
         'tlsRigour': 'normal',
         'bind': True,  # whether to bind queues/subscriptions
         'declare': True # whether to declare queues/subscriptions
       }


cfg.subscriptions = sarracenia.config.subscription.Subscriptions( [ {
   'broker': cfg.broker,
   'bindings': bindings,
   'queue' : queue
      } ] )


# set the instance number for the flow class.
cfg.no=0

cfg.finalize()

# accept/reject patterns:
pattern=".*"
#   to_match, write_to_dir, DESTFN, regex_to_match, accept=True,mirror,strip, pstrip,flatten
cfg.masks= [ ( pattern, "/tmp/flow_demo", None, re.compile(pattern), True, False, False, False, '/', None ) ]

# %% [markdown]
# ## démareurs.
# les paramètres du courtier, des liaisons et du nom de la file d'attente sont expliqués dans le bloc-notes de moth.
#
# ## cfg.download
#
# Si vous souhaitez que le flux télécharge les fichiers correspondant aux messages.
# Si vrai, il téléchargera les fichiers.
#
# ## cfg.batch
#
# Les messages sont traités par lots. Le nombre de messages à récupérer par appel à newMessages()
# est limité par le paramètre _batch_. Nous le définissons ici sur 1 afin que vous puissiez voir chaque fichier téléchargé immédiatement lorsque le message correspondant est téléchargé. vous pouvez laisser ce champ vide et la valeur par défaut est 25. Les paramètres sont une question de goût et de cas d'utilisation.
#
# ## cfg.messageCountMax
#
# Normalement, nous laissons ce paramètre à sa valeur par défaut (0) qui n'a aucun effet sur le traitement.
# à des fins de démonstration, nous limitons le nombre de messages que l'abonné traitera avec ce paramètre.
# après la réception de _messageCountMax_ messages, arrêtez le traitement.
#
# ## cfg.masks
#
# Les masques sont une forme compilée de directives d'acceptation/rejet. un relPath est comparé à la regex dans le masque.
# Si l'expression régulière correspond et que accept est True, le message est accepté pour un traitement ultérieur.
# Si l'expression régulière correspond, mais accept vaut False, le traitement du message est arrêté (le message est rejeté.)
#
# les masques sont un tuple. la signification peut être recherchée dans la page de manuel sr3(1).
#
# *  pattern_string,      la chaîne d'expression régulière d'entrée, à compiler par les routines.
# *  directory,           où mettre les fichiers téléchargés (racine de l'arborescence, lors de la mise en miroir)
# *  fn,                  transformation du filename à faire. NONE est utilisé 99% des cas d'utilisation.
# *  regex,               version regex compilée de pattern_string
# *  accept(True/False),  si le modèle correspond, acceptez le message pour un traitement ultérieur.
# *  mirror(True/False),  lors du téléchargement, créez une arborescence complète pour refléter la source, ou videz-la simplement dans le répertoire
# *  strip(True/False),   modifier le relpath en supprimant les entrées de la gauche.
# *  pstrip(True/False),  entrées de bande basées sur le modèle
# *  flatten(char ... '/' signifie ne pas aplatir.) )
#
# ## cfg.no, cfg.pid_filename
#
# Ces paramètres sont nécessaires car ils seraient normalement définis par la classe sarracenia.instance
# qui est normalement utilisée pour lancer des flux. Ils permettent de configurer des chemins d'exécution pour retry_queues et des fichiers d'état,
# afin de mémoriser les paramètres si nécessaire entre les exécutions.

# %%
subscriber = sarracenia.flow.subscribe.Subscribe( cfg )

subscriber.run()
# Out:
# 2025-05-14 11:53:18,824 [DEBUG] sarracenia.flowcb.retry __init__ sr_retry __init__
# 2025-05-14 11:53:18,824 [DEBUG] sarracenia.config add_option 0 retry_driver declared as type:<class 'str'> value:disk
# 2025-05-14 11:53:18,824 [DEBUG] sarracenia.config add_option 0 retry_refilter declared as type:<class 'bool'> value:False
# 2025-05-14 11:53:18,827 [DEBUG] sarracenia.config add_option 0 MemoryMax declared as type:<class 'int'> value:0
# 2025-05-14 11:53:18,827 [DEBUG] sarracenia.config add_option 0 MemoryBaseLineFile declared as type:<class 'int'> value:100
# 2025-05-14 11:53:18,827 [DEBUG] sarracenia.config add_option 0 MemoryMultiplier declared as type:<class 'int'> value:3
# 2025-05-14 11:53:18,828 [DEBUG] sarracenia.config add_option 0 logEvents declared as type:<class 'set'> value:{'after_post', 'after_work', 'on_housekeeping', 'after_accept'}
# 2025-05-14 11:53:18,829 [DEBUG] sarracenia.config add_option 0 logMessageDump declared as type:<class 'bool'> value:False
# 2025-05-14 11:53:18,829 [DEBUG] sarracenia.config check_undeclared_options missing defaults: {'restore', 'notify_only', 'reconnect', 'realpathFilter', 'blockSize', 'nodupe_basis', 'post_exchange', 'force_polling', 'httpsSafeQuote', 'accelWgetCommand', 'cluster', 'logMessageDump', 'exchangeSplit', 'header', 'save', 'count', 'identity', 'feeder', 'MemoryMax', 'MemoryMultiplier', 'pollUrl', 'follow_symlinks', 'post_topic', 'report_exchange', 'MemoryBaseLineFile', 'post_exchangeSplit', 'sendTo', 'exchangeSuffix', 'retry_driver', 'post_on_start', 'topic', 'inplace', 'accelCpCommand', 'post_exchangeSuffix', 'accelScpCommand'}
# 2025-05-14 11:53:18,830 [DEBUG] sarracenia.diskqueue __init__  work_retry_00 __init__
# 2025-05-14 11:53:18,981 [DEBUG] amqp _on_start Start from server, version: 0.9, properties: {'capabilities': {'publisher_confirms': True, 'exchange_exchange_bindings': True, 'basic.nack': True, 'consumer_cancel_notify': True, 'connection.blocked': True, 'consumer_priorities': True, 'authentication_failure_close': True, 'per_consumer_qos': True, 'direct_reply_to': True}, 'cluster_name': 'rabbit@hpfx2.collab.science.gc.ca', 'copyright': 'Copyright (c) 2007-2022 VMware, Inc. or its affiliates.', 'information': 'Licensed under the MPL 2.0. Website: https://rabbitmq.com', 'platform': 'Erlang/OTP 24.2.1', 'product': 'RabbitMQ', 'version': '3.9.27'}, mechanisms: [b'PLAIN', b'AMQPLAIN'], locales: ['en_US']
# 2025-05-14 11:53:19,188 [DEBUG] amqp __init__ using channel_id: 1
# 2025-05-14 11:53:19,209 [DEBUG] amqp _on_open_ok Channel open
# 2025-05-14 11:53:19,209 [DEBUG] amqp __init__ using channel_id: 2
# 2025-05-14 11:53:19,231 [DEBUG] amqp _on_open_ok Channel open
# 2025-05-14 11:53:19,415 [INFO] sarracenia.moth.amqp _queueDeclare queue declared q_anonymous_idefix.local_SomethingSessionfulToYou (as: amqps://anonymous@hpfx.collab.science.gc.ca), (messages waiting: 0)
# 2025-05-14 11:53:19,416 [INFO] sarracenia.moth.amqp getSetup binding q_anonymous_idefix.local_SomethingSessionfulToYou with v02.post.*.WXO-DD.observations.swob-ml.# to xpublic (as: amqps://anonymous@hpfx.collab.science.gc.ca)
# 2025-05-14 11:53:19,433 [DEBUG] sarracenia.moth.amqp getSetup getSetup ... Done!
# 2025-05-14 11:53:21,676 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'_format': 'v02', '_deleteOnPost': {'topic', '_format', 'ack_id', 'local_offset', 'exchange', 'subscription_index', 'subtopic'}, 'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155304', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'ALL', 'filename': 'msg_ddsr-WXO-DD_043fd1493e0e507373e43083d74c3cf5:DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155304', 'source': 'anonymous', 'mtime': '20250514T155306.958', 'atime': '20250514T155306.958', 'pubTime': '20250514T155306.958', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20250514/WXO-DD/observations/swob-ml/20250514/CWOC/2025-05-14-1552-CWOC-AUTO-minute-swob.xml', 'subtopic': ['20250514', 'WXO-DD', 'observations', 'swob-ml', '20250514', 'CWOC'], 'identity': {'method': 'md5', 'value': 'vSHfoYjhzmH2VCiVexQpZw=='}, 'size': 8519, 'exchange': 'xpublic', 'topic': 'v02.post.20250514.WXO-DD.observations.swob-ml.20250514.CWOC', 'ack_id': {'delivery_tag': 1, 'channel_id': 2, 'connection_id': '06217b39-eacf-4c8c-a090-9b0bc529394a_sub', 'broker': 'hpfx.collab.science.gc.ca:5671//'}, 'local_offset': 0, 'subscription_index': 0}
# 2025-05-14 11:53:21,676 [INFO] sarracenia.flowcb.log after_accept accepted: (lag: 14.72 )  exchange: xpublic subtopic: 20250514.WXO-DD.observations.swob-ml.20250514.CWOC a file with baseUrl: https://hpfx.collab.science.gc.ca relPath: /20250514/WXO-DD/observations/swob-ml/20250514/CWOC/2025-05-14-1552-CWOC-AUTO-minute-swob.xml sundew_extension: DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155304 id: vSHfoYj size: 8519
# 2025-05-14 11:53:21,677 [DEBUG] sarracenia.config add_option 0 accelWgetCommand declared as type:<class 'str'> value:/usr/bin/wget %s -o - -O %d
# 2025-05-14 11:53:21,678 [DEBUG] sarracenia.config add_option 0 httpsSafeQuote declared as type:<class 'str'> value:/+
# 2025-05-14 11:53:21,909 [INFO] sarracenia.flowcb.log after_work downloaded ok: /tmp/flow_demo/2025-05-14-1552-CWOC-AUTO-minute-swob.xml
# 2025-05-14 11:53:21,926 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'_format': 'v02', '_deleteOnPost': {'topic', '_format', 'ack_id', 'local_offset', 'exchange', 'subscription_index', 'subtopic'}, 'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155304', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'ALL', 'filename': 'msg_ddsr-WXO-DD_3a27b694414267403ac763a7efebf1d0:DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155304', 'source': 'anonymous', 'mtime': '20250514T155306.959', 'atime': '20250514T155306.959', 'pubTime': '20250514T155306.959', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20250514/WXO-DD/observations/swob-ml/20250514/CWSB/2025-05-14-1552-CWSB-AUTO-minute-swob.xml', 'subtopic': ['20250514', 'WXO-DD', 'observations', 'swob-ml', '20250514', 'CWSB'], 'identity': {'method': 'md5', 'value': 'hlPubx3mKui7/R1cDZBFVw=='}, 'size': 8391, 'exchange': 'xpublic', 'topic': 'v02.post.20250514.WXO-DD.observations.swob-ml.20250514.CWSB', 'ack_id': {'delivery_tag': 2, 'channel_id': 2, 'connection_id': '06217b39-eacf-4c8c-a090-9b0bc529394a_sub', 'broker': 'hpfx.collab.science.gc.ca:5671//'}, 'local_offset': 0, 'subscription_index': 0}
# 2025-05-14 11:53:21,927 [INFO] sarracenia.flowcb.log after_accept accepted: (lag: 14.97 )  exchange: xpublic subtopic: 20250514.WXO-DD.observations.swob-ml.20250514.CWSB a file with baseUrl: https://hpfx.collab.science.gc.ca relPath: /20250514/WXO-DD/observations/swob-ml/20250514/CWSB/2025-05-14-1552-CWSB-AUTO-minute-swob.xml sundew_extension: DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155304 id: hlPubx3 size: 8391
# 2025-05-14 11:53:22,138 [INFO] sarracenia.flowcb.log after_work downloaded ok: /tmp/flow_demo/2025-05-14-1552-CWSB-AUTO-minute-swob.xml
# 2025-05-14 11:53:22,159 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'_format': 'v02', '_deleteOnPost': {'topic', '_format', 'ack_id', 'local_offset', 'exchange', 'subscription_index', 'subtopic'}, 'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'ALL', 'filename': 'msg_ddsr-WXO-DD_0c7feb439766b66ef4efd67a63defc35:DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309', 'source': 'anonymous', 'mtime': '20250514T155311.968', 'atime': '20250514T155311.968', 'pubTime': '20250514T155311.968', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20250514/WXO-DD/observations/swob-ml/20250514/CWJD/2025-05-14-1552-CWJD-AUTO-minute-swob.xml', 'subtopic': ['20250514', 'WXO-DD', 'observations', 'swob-ml', '20250514', 'CWJD'], 'identity': {'method': 'md5', 'value': 'JTov+vz9n3bvOFNKpiJ+nQ=='}, 'size': 9426, 'exchange': 'xpublic', 'topic': 'v02.post.20250514.WXO-DD.observations.swob-ml.20250514.CWJD', 'ack_id': {'delivery_tag': 3, 'channel_id': 2, 'connection_id': '06217b39-eacf-4c8c-a090-9b0bc529394a_sub', 'broker': 'hpfx.collab.science.gc.ca:5671//'}, 'local_offset': 0, 'subscription_index': 0}
# 2025-05-14 11:53:22,160 [INFO] sarracenia.flowcb.log after_accept accepted: (lag: 10.19 )  exchange: xpublic subtopic: 20250514.WXO-DD.observations.swob-ml.20250514.CWJD a file with baseUrl: https://hpfx.collab.science.gc.ca relPath: /20250514/WXO-DD/observations/swob-ml/20250514/CWJD/2025-05-14-1552-CWJD-AUTO-minute-swob.xml sundew_extension: DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309 id: JTov+vz size: 9426
# 2025-05-14 11:53:22,365 [INFO] sarracenia.flowcb.log after_work downloaded ok: /tmp/flow_demo/2025-05-14-1552-CWJD-AUTO-minute-swob.xml
# 2025-05-14 11:53:22,385 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'_format': 'v02', '_deleteOnPost': {'topic', '_format', 'ack_id', 'local_offset', 'exchange', 'subscription_index', 'subtopic'}, 'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'ALL', 'filename': 'msg_ddsr-WXO-DD_4154c85a4fb579df1ab1b0404895b41c:DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309', 'source': 'anonymous', 'mtime': '20250514T155311.970', 'atime': '20250514T155311.970', 'pubTime': '20250514T155311.970', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20250514/WXO-DD/observations/swob-ml/20250514/CWUM/2025-05-14-1552-CWUM-AUTO-minute-swob.xml', 'subtopic': ['20250514', 'WXO-DD', 'observations', 'swob-ml', '20250514', 'CWUM'], 'identity': {'method': 'md5', 'value': 'AiEQRL2sdE2ClV7HbI4Nnw=='}, 'size': 8417, 'exchange': 'xpublic', 'topic': 'v02.post.20250514.WXO-DD.observations.swob-ml.20250514.CWUM', 'ack_id': {'delivery_tag': 4, 'channel_id': 2, 'connection_id': '06217b39-eacf-4c8c-a090-9b0bc529394a_sub', 'broker': 'hpfx.collab.science.gc.ca:5671//'}, 'local_offset': 0, 'subscription_index': 0}
# 2025-05-14 11:53:22,386 [INFO] sarracenia.flowcb.log after_accept accepted: (lag: 10.42 )  exchange: xpublic subtopic: 20250514.WXO-DD.observations.swob-ml.20250514.CWUM a file with baseUrl: https://hpfx.collab.science.gc.ca relPath: /20250514/WXO-DD/observations/swob-ml/20250514/CWUM/2025-05-14-1552-CWUM-AUTO-minute-swob.xml sundew_extension: DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309 id: AiEQRL2 size: 8417
# 2025-05-14 11:53:22,642 [INFO] sarracenia.flowcb.log after_work downloaded ok: /tmp/flow_demo/2025-05-14-1552-CWUM-AUTO-minute-swob.xml
# 2025-05-14 11:53:22,663 [DEBUG] sarracenia.moth.amqp getNewMessage new msg: {'_format': 'v02', '_deleteOnPost': {'topic', '_format', 'ack_id', 'local_offset', 'exchange', 'subscription_index', 'subtopic'}, 'sundew_extension': 'DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309', 'from_cluster': 'DDSR.CMC', 'to_clusters': 'ALL', 'filename': 'msg_ddsr-WXO-DD_4727d39c07091252a2de4ef9197420af:DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309', 'source': 'anonymous', 'mtime': '20250514T155311.970', 'atime': '20250514T155311.970', 'pubTime': '20250514T155311.970', 'baseUrl': 'https://hpfx.collab.science.gc.ca', 'relPath': '/20250514/WXO-DD/observations/swob-ml/20250514/CVOP/2025-05-14-1552-CVOP-AUTO-minute-swob.xml', 'subtopic': ['20250514', 'WXO-DD', 'observations', 'swob-ml', '20250514', 'CVOP'], 'identity': {'method': 'md5', 'value': 'TTYy3O2YR92YHSWf4vmjRw=='}, 'size': 6726, 'exchange': 'xpublic', 'topic': 'v02.post.20250514.WXO-DD.observations.swob-ml.20250514.CVOP', 'ack_id': {'delivery_tag': 5, 'channel_id': 2, 'connection_id': '06217b39-eacf-4c8c-a090-9b0bc529394a_sub', 'broker': 'hpfx.collab.science.gc.ca:5671//'}, 'local_offset': 0, 'subscription_index': 0}
# 2025-05-14 11:53:22,665 [INFO] sarracenia.flowcb.log after_accept accepted: (lag: 10.70 )  exchange: xpublic subtopic: 20250514.WXO-DD.observations.swob-ml.20250514.CVOP a file with baseUrl: https://hpfx.collab.science.gc.ca relPath: /20250514/WXO-DD/observations/swob-ml/20250514/CVOP/2025-05-14-1552-CVOP-AUTO-minute-swob.xml sundew_extension: DMS:WXO_RENAMED_SWOB2:MSC:XML::20250514155309 id: TTYy3O2 size: 6726
# 2025-05-14 11:53:22,851 [INFO] sarracenia.flowcb.log after_work downloaded ok: /tmp/flow_demo/2025-05-14-1552-CVOP-AUTO-minute-swob.xml
# 2025-05-14 11:53:22,852 [INFO] sarracenia.flow run 6 messages processed > messageCountMax 5
# 2025-05-14 11:53:22,852 [INFO] sarracenia.flow please_stop asked to stop
# 2025-05-14 11:53:22,852 [INFO] sarracenia.moth please_stop asked to stop
# 2025-05-14 11:53:22,853 [INFO] sarracenia.flow _runHousekeeping on_housekeeping pid: 718733 subscribe/flow_demo instance: 0
# 2025-05-14 11:53:22,853 [INFO] sarracenia.flowcb.gather.message on_housekeeping from amqps://anonymous@hpfx.collab.science.gc.ca messages: good: 5 bad: 0 bytes: 730Bytes average: 146Bytes
# 2025-05-14 11:53:22,855 [INFO] sarracenia.flowcb.housekeeping.resources on_housekeeping Current cpu_times: user=0.66 system=0.15
# 2025-05-14 11:53:22,855 [INFO] sarracenia.flowcb.housekeeping.resources on_housekeeping Current mem usage: 806.2MiB, accumulating count (5 or 5/100 so far) before self-setting threshold
# 2025-05-14 11:53:22,855 [INFO] sarracenia.flowcb.log stats version: 3.00.59rc1, started: 4 seconds ago, last_housekeeping:  4.0 seconds ago
# 2025-05-14 11:53:22,856 [INFO] sarracenia.flowcb.log stats messages received: 5, accepted: 5, rejected: 0   rate accepted: 100.0% or 1.2 m/s
# 2025-05-14 11:53:22,856 [INFO] sarracenia.flowcb.log stats files transferred: 5 bytes: 40.5KiB rate: 10.1KiB/sec
# 2025-05-14 11:53:22,856 [INFO] sarracenia.flowcb.log stats lag: average: 12.20, maximum: 14.97
# 2025-05-14 11:53:22,856 [INFO] sarracenia.flow run 6 messages processed > messageCountMax 5
# 2025-05-14 11:53:22,856 [INFO] sarracenia.flow please_stop asked to stop
# 2025-05-14 11:53:22,857 [INFO] sarracenia.moth please_stop asked to stop
# 2025-05-14 11:53:22,857 [INFO] sarracenia.flow _runHousekeeping on_housekeeping pid: 718733 subscribe/flow_demo instance: 0
# 2025-05-14 11:53:22,857 [INFO] sarracenia.flowcb.gather.message on_housekeeping from amqps://anonymous@hpfx.collab.science.gc.ca messages: good: 0 bad: 0 bytes: 0Bytes average: 0Bytes
# 2025-05-14 11:53:22,858 [INFO] sarracenia.flowcb.housekeeping.resources on_housekeeping Current cpu_times: user=0.67 system=0.15
# 2025-05-14 11:53:22,858 [INFO] sarracenia.flowcb.housekeeping.resources on_housekeeping Current mem usage: 806.2MiB, accumulating count (5 or 5/100 so far) before self-setting threshold
# 2025-05-14 11:53:22,858 [INFO] sarracenia.flowcb.log stats version: 3.00.59rc1, started: 4 seconds ago, last_housekeeping:  0.0 seconds ago
# 2025-05-14 11:53:22,858 [INFO] sarracenia.flowcb.log stats messages received: 0, accepted: 0, rejected: 0   rate accepted: 0.0% or 0.0 m/s
# 2025-05-14 11:53:22,858 [INFO] sarracenia.flowcb.log stats files transferred: 0 bytes: 0Bytes rate: 0Bytes/sec
# 2025-05-14 11:53:22,877 [DEBUG] amqp collect Closed channel #1
# 2025-05-14 11:53:22,877 [DEBUG] amqp collect Closed channel #2
# 2025-05-14 11:53:22,878 [INFO] sarracenia.flow close flow/close completed cleanly pid: 718733 subscribe/flow_demo instance: 0

# %% [markdown]
# ## Conclusion:
#
# Avec la classe sarracenia.flow, une méthode de fonctionnement asynchrone est prise en charge, elle peut être personnalisée à l'aide de la classe flowcb (rappel de flux) pour introduire un traitement spécifique à des moments spécifiques. C'est comme l'invocation d'une seule instance à partir de la ligne de commande, sauf que toute la configuration est effectuée dans python en définissant des champs cfg, plutôt qu'en utilisant le langage de configuration.
#
# Qu'est-ce qui est perdu par rapport à l'utilisation de l'outil de ligne de commande :
#
# * possibilité d'utiliser le langage de configuration (légèrement plus simple que d'attribuer des valeurs à l'objet cfg)
# * exécution facile de plusieurs instances,
# * surveillance coordonnée des instances (redémarrages en cas d'échec, et nombre programmable d'abonnés démarrés par configuration.)
# * gestion des fichiers journaux.
#
# L'outil de ligne de commande fournit ces fonctionnalités supplémentaires.
